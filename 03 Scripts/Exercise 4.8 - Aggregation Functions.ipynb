# %% [markdown]
# # Table of Contents
#
# ### Included in this file
#
# 01 Importing libraries and data\
# 02 Groupby & agg. functions\
#    a. Create loyalty flag\
#    b. Deriving columns with loc function\
#    c. Create Spending flags \
#    d. Create frequency flags \
# 03 Export

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/biancaskyehoney/Documents/Instacart Basket Analysis '

# %%
# Specify the correct file path and name
pickle_file_path = os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl')

# Read the Pickle file using pd.read_pickle()
df_ords_prods_merge = pd.read_pickle(pickle_file_path)

# %%
df = df_ords_prods_merge

# %%
df.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN            1         196                  1
# 1                    15.0            0         196                  1
# 2                    21.0            0         196                  1
# 3                    29.0            0         196                  1
# 4                    28.0            0         196                  1
#
#    reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# ...

# %% [markdown]
# ### 2.  groupby and agg() function

# %%
# group data by specific column name

df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# the above differs from previously calculated subset means in the sense that all department Id's are now accounted for and the previiously calculated means (as part of the subset) have decreased slightly.

# %% [markdown]
# ### 2a. Create loyalty flag
#    Aggregate data with transform

# %%
# Creating loyatly flag for customers

df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
# ...

# %% [markdown]
# ### 2b. Deriving columns with loc function

# %%
# Deriving columns with loc funtion

df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
# Calculate the average price per user using transform

df['average_price'] = df.groupby('user_id')['prices'].transform(np.mean)

# %% [markdown]
# ### 2c. Create Spending flags

# %%
# Create spending flags based on average prices

df['spending_flag'] = 'Low spender'

# %%
df.loc[df['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
# ...

# %%
# Determining frequent vs. non-frequent customers

df['median_days'] = df.groupby('user_id')['days_since_prior_order'].transform(np.median)

# %%
df.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN            1         196                  1
# 1                    15.0            0         196                  1
# 2                    21.0            0         196                  1
# 3                    29.0            0         196                  1
# 4                    28.0            0         196                  1
#
#    reordered  ...    day_category  slowest_days     busiest_days  \
# ...

# %% [markdown]
# ### 2d. Create frequency flags

# %%
# Create order frequency flags

df.loc[df['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df.loc[(df['median_days'] > 10) & (df['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
df.loc[df['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequencies of spending flags for accuracy

df['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
# Check null values

print(df[df.frequency_flag.isnull()])
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 13645692    895835   159838             1                   0
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 24138593    895835   159838             1                   0
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 13645692                 17                     NaN            1       10749
# 17251990                 17                     NaN            1       33401
# 17622767                 17                     NaN            1       23695
# 24138593                 17                     NaN            1       21334
# 25880002                 17                     NaN            1       22198
#
#           add_to_cart_order  reordered  ... slowest_days  busiest_days  \
# ...

# %%
# median cannot be created for customer as they have only had 1 order, therefore can qualify as non frequent customer

# %%
df['frequency_flag'].fillna("Non-frequent customer", inplace = True)

# %%
df['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636442
# Name: frequency_flag, dtype: int64

# %%
#Export

df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated.pkl'))
